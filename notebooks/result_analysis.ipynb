# %%
import numpy as np
import pandas as pd

# %%
bootstrap_results = pd.read_csv('../output/bootstrap_results.csv')

# %%
bootstrap_results.head()
# Out:
#          LR        RF       ADA        GB       QDA       LDA  LinearSVM  \
# 0  0.498889  0.502222  0.527778  0.477778  0.353333  0.406667   0.560000
# 1  0.564444  0.533333  0.503333  0.474444  0.467778  0.506667   0.523333
# 2  0.416667  0.510000  0.491111  0.595556  0.605556  0.533333   0.432222
# 3  0.530000  0.504444  0.501111  0.407778  0.461111  0.387778   0.470000
# 4  0.572222  0.346667  0.445556  0.415556  0.497778  0.540000   0.461111
#
#      RBFSVM Subject feature_size
# 0  0.343333   NF101     (96, 12)
# 1  0.365556   NF101     (96, 12)
# 2  0.333333   NF101     (96, 12)
# 3  0.345556   NF101     (96, 12)
# 4  0.387778   NF101     (96, 12)

# %%
bt_agg_subject_mean = bootstrap_results.groupby(['Subject']).mean()

# %%
bt_agg_subject_mean
# Out:
#                LR        RF       ADA        GB       QDA       LDA  \
# Subject
# NF101    0.487832  0.488263  0.492080  0.493566  0.499921  0.480603
# NF103    0.490976  0.493016  0.489967  0.492536  0.494113  0.485563
# NF104    0.487431  0.490629  0.486331  0.493986  0.496457  0.489461
# NF105    0.484795  0.482800  0.489750  0.486090  0.473125  0.483610
# NF106    0.484439  0.492659  0.489501  0.496980  0.496797  0.483373
# NF107    0.485594  0.493549  0.491141  0.489414  0.495424  0.490422
# NF108    0.485099  0.488082  0.491709  0.493891  0.497139  0.482178
# NF109    0.489302  0.491162  0.496429  0.492381  0.490716  0.487310
# NF110    0.487757  0.490521  0.490372  0.492441  0.499328  0.485490
#
#          LinearSVM    RBFSVM
# Subject
# NF101     0.494634  0.376753
# NF103     0.494792  0.378888
# NF104     0.495818  0.380041
# NF105     0.490190  0.318855
# NF106     0.494490  0.378492
# NF107     0.496870  0.377622
# NF108     0.495574  0.377593
# NF109     0.497921  0.378139
# NF110     0.494538  0.375922

# %%
bt_agg_subject_std = bootstrap_results.groupby(['Subject']).std()

# %%
bt_agg_subject_std
# Out:
#                LR        RF       ADA        GB       QDA       LDA  \
# Subject
# NF101    0.060158  0.057212  0.061335  0.063842  0.056108  0.068974
# NF103    0.067695  0.060267  0.063409  0.065279  0.062080  0.068770
# NF104    0.066611  0.058200  0.061838  0.065014  0.057559  0.066170
# NF105    0.089002  0.083826  0.089456  0.094474  0.086350  0.093076
# NF106    0.063666  0.057987  0.061257  0.065847  0.052748  0.066570
# NF107    0.067086  0.059627  0.063205  0.068151  0.061916  0.066753
# NF108    0.064406  0.060374  0.064729  0.067952  0.060138  0.063413
# NF109    0.065671  0.060471  0.063037  0.065841  0.061344  0.064933
# NF110    0.064274  0.060406  0.063908  0.068435  0.055027  0.065694
#
#          LinearSVM    RBFSVM
# Subject
# NF101     0.051872  0.030551
# NF103     0.051218  0.031209
# NF104     0.053529  0.030495
# NF105     0.077238  0.041781
# NF106     0.049947  0.029384
# NF107     0.054029  0.030593
# NF108     0.051508  0.032249
# NF109     0.050555  0.030425
# NF110     0.051255  0.031880

# %%
actual_results = pd.read_csv('../output/results.csv')

# %%
actual_agg_subject_mean = actual_results.groupby(['Subject']).mean()

# %%
actual_agg_subject_mean
# Out:
#                      LR        RF       ADA        GB       QDA       LDA  \
# Subject
# ../data\NF101  0.656667  0.605556  0.527778  0.663333  0.645556  0.603333
# ../data\NF103  0.543333  0.653333  0.665556  0.728889  0.636667  0.533333
# ../data\NF104  0.440000  0.446667  0.544444  0.511111  0.458889  0.430000
# ../data\NF105  0.625000  0.725000  0.725000  0.830000  0.610000  0.560000
# ../data\NF106  0.696667  0.741111  0.721111  0.710000  0.731111  0.646667
# ../data\NF107  0.395556  0.522222  0.563333  0.522222  0.593333  0.448889
# ../data\NF108  0.574444  0.498889  0.543333  0.440000  0.565556  0.574444
# ../data\NF109  0.532222  0.667778  0.672222  0.592222  0.636667  0.551111
# ../data\NF110  0.633333  0.553333  0.611111  0.610000  0.557778  0.603333
#
#                LinearSVM    RBFSVM
# Subject
# ../data\NF101   0.666667  0.336667
# ../data\NF103   0.636667  0.336667
# ../data\NF104   0.397778  0.336667
# ../data\NF105   0.645000  0.335000
# ../data\NF106   0.744444  0.336667
# ../data\NF107   0.493333  0.336667
# ../data\NF108   0.501111  0.336667
# ../data\NF109   0.571111  0.336667
# ../data\NF110   0.464444  0.336667
